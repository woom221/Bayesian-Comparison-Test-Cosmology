# %% [markdown]
# ## Polychord
#
# Polychord is used to calculate the evidences (marginal likelihood) which are ultimately used to calculate the bayes factor.

# %%
from cobaya.run import run
import healpy as hp
import pyccl as ccl

import numpy as np
import matplotlib.pyplot as plt
import itertools
import time
import os

# %% [markdown]
# ## Model Description
#
# We define the tools needed for analysis.
#
# The tools include
#
# - Binning function of the multipoles
# - Simulating the cosmology and sky map using the weak lensing and galaxy cluster angular power spectra

# %%
def create_bin(min_ell, max_ell, n, cgg, ckg, ckk):
    """
    Groups the range of multipoles to bins from the angular power spectra.
    """
    x = np.arange(min_ell, max_ell, 1)
    bin_edges = np.linspace(np.min(x), np.max(x), n)
    bin_centers, galaxy_galaxy_bin = bin_mat(x, np.array(cgg), bin_edges)
    _, lensing_galaxy_bin = bin_mat(x, np.array(ckg), bin_edges)
    _, lensing_lensing_bin = bin_mat(x, np.array(ckk), bin_edges)
    return bin_centers, galaxy_galaxy_bin, lensing_galaxy_bin,lensing_lensing_bin

def bin_mat(r=[],mat=[],r_bins=[]):
    """
    Divides the range of l using the edges provided from r_bins.
    Returns the center of each bins and matrix of binned data
    """
    bin_center=0.5*(r_bins[1:]+r_bins[:-1])
    n_bins=len(bin_center)
    ndim=len(mat.shape)
    mat_int=np.zeros([n_bins]*ndim,dtype='float64')
    norm_int=np.zeros([n_bins]*ndim,dtype='float64')
    bin_idx=np.digitize(r,r_bins)-1
    r2=np.sort(np.unique(np.append(r,r_bins))) #this takes care of problems around bin edges
    dr=np.gradient(r2)
    r2_idx=[i for i in np.arange(len(r2)) if r2[i] in r]
    dr=dr[r2_idx]
    r_dr=r*dr

    ls=['i','j','k','l']
    s1=ls[0]
    s2=ls[0]
    r_dr_m=r_dr
    for i in np.arange(ndim-1):
        s1=s2+','+ls[i+1]
        s2+=ls[i+1]
        r_dr_m=np.einsum(s1+'->'+s2,r_dr_m,r_dr)#works ok for 2-d case

    mat_r_dr=mat*r_dr_m
    for indxs in itertools.product(np.arange(min(bin_idx),n_bins),repeat=ndim):
        # x={} #np.zeros_like(mat_r_dr,dtype='bool')
        norm_ijk=1
        mat_t=[]
        for nd in np.arange(ndim):
            slc = [slice(None)] * (ndim)
            #x[nd]=bin_idx==indxs[nd]
            slc[nd]=bin_idx==indxs[nd]
            if nd==0:
                mat_t=mat_r_dr[slc[0]]
            else:
                mat_t=mat_t[slc[0]]
            norm_ijk*=np.sum(r_dr[slc[nd]])
        if norm_ijk==0:
            continue
        mat_int[indxs]=np.sum(mat_t)/norm_ijk
        norm_int[indxs]=norm_ijk
    return bin_center,mat_int

def default_nz(z):
    """
    Basic Galaxy distribution used for populating the Universe.
    We use a simple Gaussian centered at 0.5 with standard deviation 0.1
    """
    return np.exp(-0.5 * ((z - 0.5) / 0.1) ** 2)

def default_b1(z):
    """
    Multipkication factor to describe the relationship between matter and galaxies. 
    Here, we assume the galaxy distribution exactly describes the matter density field.
    """
    return np.ones_like(z)

class CosmologicalModel_lambda_CDM:
    """
    This class populates the cosmology that will be used for further analysis.
    The populated cosmology can be based on lambda CDM or dynamic dark energy depending on the 
    parameter choices (here we use lambda CDM).

    We use galaxy clustering and weak lensing and their angular power spectra (individual & cross correlation) 
    for the analysis.
    """
    def __init__(self, z_min=0, z_max=1, z_step=256, max_ell=1000, omega_c=0.25, omega_b=0.05,
                 h=0.67, a_s=2.1e-9, n_s=0.96, m_nu=0.06):
        self.z_min = z_min
        self.z_max = z_max
        self.z_step = z_step
        self.max_ell = max_ell
        self.z = np.linspace(self.z_min, self.z_max, self.z_step)
        self.omega_c = omega_c
        self.omega_b = omega_b
        self.h = h
        self.a_s = a_s
        self.n_s = n_s
        self.m_nu = m_nu
        self.ells = np.arange(0, self.max_ell, 1)
        self.model = ccl.Cosmology(Omega_c=omega_c, Omega_b=omega_b, h=h, A_s=a_s, 
                                   n_s=n_s, m_nu=m_nu, mass_split="single", 
                                   transfer_function="boltzmann_camb")

    def generate_galaxy_clustering(self, nz_fn=default_nz, b1_fn=default_b1):
        nz = nz_fn(self.z)
        b1 = b1_fn(self.z)
        return ccl.NumberCountsTracer(self.model, has_rsd=False, dndz=(self.z, nz), bias=(self.z, b1))

    def generate_lensing(self, z_source=1100):
        return ccl.CMBLensingTracer(self.model, z_source=z_source)

    def generate_angular_ps(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, output_type="all", is_plot=True):
        galaxy_dist = self.generate_galaxy_clustering(nz_fn, b1_fn)
        lensing_dist = self.generate_lensing(z_source=z_source)
        cgg = ccl.angular_cl(self.model, galaxy_dist, galaxy_dist, self.ells)
        ckk = ccl.angular_cl(self.model, lensing_dist, lensing_dist, self.ells)
        ckg = ccl.angular_cl(self.model, lensing_dist, galaxy_dist, self.ells)
        if output_type == "cgg":
            if is_plot:
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return cgg
        elif output_type == "ckg":
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckg
        elif output_type == "ckk":
            if is_plot:
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckk
        else:
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.legend(loc="best")
                plt.show()
            return cgg, ckg, ckk

    def generate_survey_map(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, nside=1024, pol=False, is_plot=True):
        np.random.seed(998905029)
        cl = self.generate_angular_ps(nz_fn=nz_fn, b1_fn=b1_fn, z_source=z_source, is_plot=False)
        delta_g, delta_k = hp.synfast(list(cl), nside=nside, pol=pol)
        if is_plot:
            hp.mollview(delta_g, cmap='seismic', min=-.1, max=.1, title="Galaxy Overdensity Field")
            hp.mollview(delta_k, cmap='seismic', min=-.1, max=.1, title="Lensing Overdensity Field")
            plt.show()
        return delta_g, delta_k
    
class CosmologicalModel_w_CDM:
    def __init__(self, z_min=0, z_max=1, z_step=256, max_ell=1000, omega_c=0.25, omega_b=0.05,
                 h=0.67, a_s=2.1e-9, n_s=0.96, m_nu=0.06, w0=-1, wa=0):
        self.z_min = z_min
        self.z_max = z_max
        self.z_step = z_step
        self.max_ell = max_ell
        self.z = np.linspace(self.z_min, self.z_max, self.z_step)
        self.omega_c = omega_c
        self.omega_b = omega_b
        self.h = h
        self.a_s = a_s
        self.n_s = n_s
        self.m_nu = m_nu
        self.w0 = w0
        self.wa = wa
        self.ells = np.arange(0, self.max_ell, 1)
        self.model = ccl.Cosmology(Omega_c=omega_c, Omega_b=omega_b, h=h, A_s=a_s, 
                                   n_s=n_s, m_nu=m_nu, w0=w0, wa=wa, mass_split="single", 
                                   transfer_function="boltzmann_camb", 
                                   extra_parameters={"camb": {"dark_energy_model": "ppf"}})

    def generate_galaxy_clustering(self, nz_fn=default_nz, b1_fn=default_b1):
        nz = nz_fn(self.z)
        b1 = b1_fn(self.z)
        return ccl.NumberCountsTracer(self.model, has_rsd=False, dndz=(self.z, nz), bias=(self.z, b1))

    def generate_lensing(self, z_source=1100):
        return ccl.CMBLensingTracer(self.model, z_source=z_source)

    def generate_angular_ps(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, output_type="all", is_plot=True):
        galaxy_dist = self.generate_galaxy_clustering(nz_fn, b1_fn)
        lensing_dist = self.generate_lensing(z_source=z_source)
        cgg = ccl.angular_cl(self.model, galaxy_dist, galaxy_dist, self.ells)
        ckk = ccl.angular_cl(self.model, lensing_dist, lensing_dist, self.ells)
        ckg = ccl.angular_cl(self.model, lensing_dist, galaxy_dist, self.ells)
        if output_type == "cgg":
            if is_plot:
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return cgg
        elif output_type == "ckg":
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckg
        elif output_type == "ckk":
            if is_plot:
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckk
        else:
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.legend(loc="best")
                plt.show()
            return cgg, ckg, ckk

    def generate_survey_map(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, nside=1024, pol=False, is_plot=True):
        np.random.seed(998905029)
        cl = self.generate_angular_ps(nz_fn=nz_fn, b1_fn=b1_fn, z_source=z_source, is_plot=False)
        delta_g, delta_k = hp.synfast(list(cl), nside=nside, pol=pol)
        if is_plot:
            hp.mollview(delta_g, cmap='seismic', min=-.1, max=.1, title="Galaxy Overdensity Field")
            hp.mollview(delta_k, cmap='seismic', min=-.1, max=.1, title="Lensing Overdensity Field")
            plt.show()
        return delta_g, delta_k

# %% [markdown]
# ## Model Set up
#
# Using the randomly selected data points from reasonable ditributions, we have already collected power spectra
# from galaxy clustering, weak lensing, and their cross correlation.
#
# Covalence matrix is also formed using the power spectra.
#
# We develop different models to compare the evidences using the Bayes Factor.
#
# The models include:
#
# model_1: lambda CDM with fixed neutrino mass
# model_2: lambda CDM with varying neutrino mass
# model_3: dynamic dark energy model with fixed neutrino mass

# %%
max_ell = 1000
min_ell = 75
n = 10

# load the stored data (angular power spectra and covalence matrix)
stacked_ps = np.load("Data/Model_1_Model_3_Comparison/stacked_ps_5_param__w0_wa_-0.95_-0.1_1_3.npy", allow_pickle=True)
cov = np.load("Data/Model_1_Model_3_Comparison/cov_5_param__w0_wa_-0.95_-0.1_1_3.npy", allow_pickle=True)


def generate_power_spectra_model_1(omega_c, n_s, lnas):
    m_nu = 0.06
    h = 0.6766
    omega_b = 0.02218 / (h**2)
    a_s = np.exp(lnas) / (10**10)
    model = CosmologicalModel_lambda_CDM(h=h, omega_b=omega_b, omega_c=omega_c, n_s=n_s, a_s=a_s, m_nu=m_nu, max_ell=max_ell)
    cgg, ckg, ckk = model.generate_angular_ps(is_plot=False)
    _, cgg_bins, ckg_bins, ckk_bins = create_bin(min_ell, max_ell, n + 1, cgg[min_ell:], ckg[min_ell:], ckk[min_ell:])
    return np.hstack((cgg_bins, ckg_bins, ckk_bins)).flatten()

def generate_power_spectra_model_2(omega_c, n_s, lnas, m_nu):
    h = 0.6766
    omega_b = 0.02218 / (h**2)
    a_s = np.exp(lnas) / (10**10)
    model = CosmologicalModel_lambda_CDM(h=h, omega_b=omega_b, omega_c=omega_c, n_s=n_s, a_s=a_s, m_nu=m_nu, max_ell=max_ell)
    cgg, ckg, ckk = model.generate_angular_ps(is_plot=False)
    _, cgg_bins, ckg_bins, ckk_bins = create_bin(min_ell, max_ell, n + 1, cgg[min_ell:], ckg[min_ell:], ckk[min_ell:])
    return np.hstack((cgg_bins, ckg_bins, ckk_bins)).flatten()

def generate_power_spectra_model_3(omega_c, n_s, lnas, w0, wa):
    m_nu = 0.06
    h = 0.6766
    omega_b = 0.02218 / (h**2)
    a_s = np.exp(lnas) / (10**10)
    model = CosmologicalModel_w_CDM(h=h, omega_b=omega_b, omega_c=omega_c, n_s=n_s, a_s=a_s, m_nu=m_nu, w0=w0, wa=wa, max_ell=max_ell)
    cgg, ckg, ckk = model.generate_angular_ps(is_plot=False)
    _, cgg_bins, ckg_bins, ckk_bins = create_bin(min_ell, max_ell, n + 1, cgg[min_ell:], ckg[min_ell:], ckk[min_ell:])
    return np.hstack((cgg_bins, ckg_bins, ckk_bins)).flatten()

def log_likelihood_model_1(omega_c, n_s, lnas):
    mu = generate_power_spectra_model_1(omega_c, n_s, lnas)
    diff = stacked_ps - mu
    return -0.5 * np.dot(diff, np.dot(np.linalg.inv(cov), diff.T)).item()


def log_likelihood_model_2(omega_c, n_s, lnas, m_nu):
    mu = generate_power_spectra_model_2(omega_c, n_s, lnas, m_nu)
    diff = stacked_ps - mu
    return -0.5 * np.dot(diff, np.dot(np.linalg.inv(cov), diff.T)).item()

def log_likelihood_model_3(omega_c, n_s, lnas, w0, wa):
    mu = generate_power_spectra_model_3(omega_c, n_s, lnas, w0, wa)
    diff = stacked_ps - mu
    return -0.5 * np.dot(diff, np.dot(np.linalg.inv(cov), diff.T)).item()

# for file naming purposes
def get_unique_run_number(base_name):
    run_number = 1
    while os.path.exists(f"{base_name}" + f"{run_number}" + "_model_2" + ".logZ"):
        run_number += 1
    return run_number

# restrictions on w0 and wa
def prior_w0_wa(w0, wa):
    if w0 + wa >= 0:
        return -np.inf 
    else:
        return 0 
    
# function to run PolyChord and return log-evidence
def run_polychord(info):
    start_time = time.time()
    results = run(info)
    end_time = time.time()
    print(f"It took {round((end_time - start_time)/3600, 2)} hours to run")
    return results

# %%
# we run polychord utilizing priors referred from DESI and Plank's 2018 results.

def main():
  # base output directory
  output_base = "polychord_output_directory/run"
  run_number = get_unique_run_number(output_base)

  # configuration for Model 1 (lambda CDM)
  info_model_1 = {
      "likelihood": {
          "likelihood_CAMB": log_likelihood_model_1
      },
      "params": {
          "omega_c": {"prior": {"min": 0.1, "max": 0.9}, "latex": r"\Omega_{c}"},
          "n_s": {"prior": {"min": 0.8, "max": 1.2}, "latex": r"n_{s}"},
          "lnas": {"prior": {"min": 1.61, "max": 3.91}, "latex": r"a_{s}"}
      },
      "sampler": {
          "polychord": {
              "path": "/Users/seanyi/Documents/polychord/PolyChordLite",
              "nlive": 32,
              "num_repeats": 5,
              "precision_criterion": 0.2
          }
      },
      "output": f"{output_base}{run_number}_model_1_-0.95_-0.1",
  }

  # configuration for Model 2 (varying neutrino mass)
  info_model_3_wide = {
      "likelihood": {
          "likelihood_CAMB": log_likelihood_model_3
      },
      "params": {
          "omega_c": {"prior": {"min": 0.1, "max": 0.9}, "latex": r"\Omega_{c}"},
          "n_s": {"prior": {"min": 0.8, "max": 1.2}, "latex": r"n_{s}"},
          "lnas": {"prior": {"min": 1.61, "max": 3.91}, "latex": r"a_{s}"},
          "w0": {"prior": {"min": -5, "max": 1}, "latex": r"a_{s}"},
          "wa": {"prior": {"min": -5, "max": 2}, "latex": r"a_{s}"}
      },
      "prior": {"function": prior_w0_wa},
      "sampler": {
          "polychord": {
              "path": "/Users/seanyi/Documents/polychord/PolyChordLite",
              "nlive": 32,
              "num_repeats": 5,
              "precision_criterion": 0.2
          }
      },
      "output": f"{output_base}{run_number}_model_3_w0_wa_-0.95_-0.1_wide",
  }

  info_model_3_narrow = {
      "likelihood": {
          "likelihood_CAMB": log_likelihood_model_3
      },
      "params": {
          "omega_c": {"prior": {"min": 0.1, "max": 0.9}, "latex": r"\Omega_{c}"},
          "n_s": {"prior": {"min": 0.8, "max": 1.2}, "latex": r"n_{s}"},
          "lnas": {"prior": {"min": 1.61, "max": 3.91}, "latex": r"a_{s}"},
          "w0": {"prior": {"min": -3, "max": 1}, "latex": r"a_{s}"},
          "wa": {"prior": {"min": -3, "max": 2}, "latex": r"a_{s}"}
      },
      "prior": {"function": prior_w0_wa},
      "sampler": {
          "polychord": {
              "path": "/Users/seanyi/Documents/polychord/PolyChordLite",
              "nlive": 32,
              "num_repeats": 5,
              "precision_criterion": 0.2
          }
      },
      "output": f"{output_base}{run_number}_model_3_w0_wa_-0.95_-0.1_narrow",
  }

  # run PolyChord for Model 3
  run_polychord(info_model_3_wide)
  run_polychord(info_model_3_narrow)

  # run PolyChord for Model 1
  run_polychord(info_model_1)

# %%
main()
# Out:
# [output] Output to be read-from/written-into folder 'polychord_output_directory', with prefix 'run1_model_3_w0_wa_-0.95_-0.1_wide'
# [parameterization] *WARNING* There are repeated parameter labels: {'a_{s}': ['lnas', 'w0', 'wa']}
# [prior] *WARNING* External prior 'function' loaded. Mind that it might not be normalized!
# [likelihood_camb] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /Users/seanyi/Documents/polychord/PolyChordLite/build/lib.macosx-11.0-arm64-cpython-311/pypolychord
# [Seans-MacBook-Pro-3.local:72530] shmem: mmap: an error occurred while determining whether or not /var/folders/w1/36c6k6fx2bx5_d7s_9z_nnhr0000gn/T//ompi.Seans-MacBook-Pro-3.501/jf.0/3561750528/sm_segment.Seans-MacBook-Pro-3.501.d44c0000.0 could be created.
# [polychord] Storing raw PolyChord output in 'polychord_output_directory/run1_model_3_w0_wa_-0.95_-0.1_wide_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {likelihood_CAMB: 1.46}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['omega_c', 'n_s', 'lnas', 'w0', 'wa']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      32
# nDims    :       5
# nDerived :       3
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to polychord_output_directory/run1_model_3_w0_wa_-0.95_-0.1_wide_polychord_raw/run1_model_3_w0_wa_-0.95_-0.1_wide.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            5
# started sampling
#
# ________________
# lives      | 32 |
# phantoms   |  4 |
# posteriors |289 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 289
# nposterior =                 289
# nequals    =                   1
# nlike      =                 331
# <nlike>    =           0.34   (           0.07 per slice )
# log(Z)     =       -44155.27 +/-  0.83
# log(Z_1)   =       -44155.27 +/-  0.83 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   | 86 |
# posteriors |322 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 322
# nposterior =                 322
# nequals    =                   1
# nlike      =                 857
# <nlike>    =          16.44   (           3.29 per slice )
# log(Z)     =       -25130.09 +/-  0.85
# log(Z_1)   =       -25130.09 +/-  0.85 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |116 |
# posteriors |355 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 355
# nposterior =                 355
# nequals    =                   1
# nlike      =                1423
# <nlike>    =          17.69   (           3.54 per slice )
# log(Z)     =       -15177.71 +/-  0.87
# log(Z_1)   =       -15177.71 +/-  0.87 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |110 |
# posteriors |388 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 388
# nposterior =                 388
# nequals    =                   1
# nlike      =                2032
# <nlike>    =          19.03   (           3.81 per slice )
# log(Z)     =        -6855.06 +/-  0.86
# log(Z_1)   =        -6855.06 +/-  0.86 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |128 |
# posteriors |421 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 421
# nposterior =                 421
# nequals    =                   1
# nlike      =                2728
# <nlike>    =          21.75   (           4.35 per slice )
# log(Z)     =        -3530.75 +/-  0.84
# log(Z_1)   =        -3530.75 +/-  0.84 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |129 |
# posteriors |454 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 454
# nposterior =                 454
# nequals    =                   1
# nlike      =                3434
# <nlike>    =          22.06   (           4.41 per slice )
# log(Z)     =        -1887.84 +/-  0.92
# log(Z_1)   =        -1887.84 +/-  0.92 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |118 |
# posteriors |487 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 487
# nposterior =                 487
# nequals    =                   1
# nlike      =                4378
# <nlike>    =          29.50   (           5.90 per slice )
# log(Z)     =         -921.93 +/-  0.81
# log(Z_1)   =         -921.93 +/-  0.81 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |130 |
# posteriors |520 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 520
# nposterior =                 520
# nequals    =                   1
# nlike      =                5238
# <nlike>    =          26.88   (           5.38 per slice )
# log(Z)     =         -557.14 +/-  0.94
# log(Z_1)   =         -557.14 +/-  0.94 (still evaluating)
#
#
#
# _____________________
# lives      | 21 | 11 |
# phantoms   | 67 | 37 |
# posteriors |545 |527 |
# equals     |  1 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 552
# nposterior =                 552
# nequals    =                   1
# nlike      =                6140
# <nlike>    =          28.19   (           5.64 per slice )
# log(Z)     =         -314.79 +/-  0.97
# log(Z_1)   =         -314.79 +/-  0.97 (still evaluating)
# log(Z_2)   =         -329.61 +/-  0.79 (still evaluating)
#
#
#
# _____________________
# lives      | 21 | 11 |
# phantoms   | 65 | 46 |
# posteriors |572 |535 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 587
# nposterior =                 587
# nequals    =                   1
# nlike      =                7010
# <nlike>    =          27.19   (           5.44 per slice )
# log(Z)     =         -213.10 +/-  0.98
# log(Z_1)   =         -213.15 +/-  1.00 (still evaluating)
# log(Z_2)   =         -216.50 +/-  0.99 (still evaluating)
#
#
#
# _____________________
# lives      | 20 | 12 |
# phantoms   | 91 | 69 |
# posteriors |594 |547 |
# equals     |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 621
# nposterior =                 621
# nequals    =                   2
# nlike      =                7829
# <nlike>    =          25.59   (           5.12 per slice )
# log(Z)     =         -171.75 +/-  0.77
# log(Z_1)   =         -171.77 +/-  0.78 (still evaluating)
# log(Z_2)   =         -176.52 +/-  1.03 (still evaluating)
#
#
#
# _____________________
# lives      | 20 | 12 |
# phantoms   |123 | 66 |
# posteriors |611 |564 |
# equals     |  1 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 655
# nposterior =                 655
# nequals    =                   3
# nlike      =                8819
# <nlike>    =          30.94   (           6.19 per slice )
# log(Z)     =         -126.47 +/-  0.89
# log(Z_1)   =         -126.47 +/-  0.89 (still evaluating)
# log(Z_2)   =         -135.22 +/-  1.03 (still evaluating)
#
#
#
# _____________________
# lives      | 21 | 11 |
# phantoms   |125 | 52 |
# posteriors |633 |576 |
# equals     |  2 |  3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 689
# nposterior =                 689
# nequals    =                   2
# nlike      =                9705
# <nlike>    =          27.69   (           5.54 per slice )
# log(Z)     =         -100.57 +/-  0.83
# log(Z_1)   =         -100.58 +/-  0.84 (still evaluating)
# log(Z_2)   =         -105.67 +/-  0.93 (still evaluating)
#
#
#
# _____________________
# lives      | 20 | 12 |
# phantoms   |107 | 43 |
# posteriors |657 |587 |
# equals     |  1 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 724
# nposterior =                 724
# nequals    =                   1
# nlike      =               10611
# <nlike>    =          28.31   (           5.66 per slice )
# log(Z)     =          -75.40 +/-  0.93
# log(Z_1)   =          -75.53 +/-  0.98 (still evaluating)
# log(Z_2)   =          -77.79 +/-  0.85 (still evaluating)
#
#
#
# _____________________
# lives      | 17 | 15 |
# phantoms   | 90 | 62 |
# posteriors |677 |601 |
# equals     |  3 |  4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 758
# nposterior =                 758
# nequals    =                   5
# nlike      =               11573
# <nlike>    =          30.06   (           6.01 per slice )
# log(Z)     =          -60.65 +/-  0.75
# log(Z_1)   =          -61.13 +/-  0.84 (still evaluating)
# log(Z_2)   =          -61.93 +/-  0.97 (still evaluating)
#
#
#
# _____________________
# lives      | 25 |  7 |
# phantoms   |123 | 31 |
# posteriors |693 |622 |
# equals     |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 795
# nposterior =                 795
# nequals    =                   6
# nlike      =               12585
# <nlike>    =          31.62   (           6.33 per slice )
# log(Z)     =          -51.02 +/-  0.82
# log(Z_1)   =          -51.51 +/-  0.91 (still evaluating)
# log(Z_2)   =          -52.40 +/-  1.10 (still evaluating)
#
#
#
# _____________________
# lives      | 31 |  1 |
# phantoms   |116 |  5 |
# posteriors |719 |630 |
# equals     |  5 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 829
# nposterior =                 829
# nequals    =                   4
# nlike      =               13541
# <nlike>    =          29.88   (           5.97 per slice )
# log(Z)     =          -39.45 +/-  0.81
# log(Z_1)   =          -39.73 +/-  0.86 (still evaluating)
# log(Z_2)   =          -41.45 +/-  1.26 (still evaluating)
#
#
#
# _____________________
# lives      | 30 |  2 |
# phantoms   |113 | 14 |
# posteriors |746 |724 |
# equals     |  7 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 862
# nposterior =                 862
# nequals    =                   8
# nlike      =               14385
# <nlike>    =          26.38   (           5.28 per slice )
# log(Z)     =          -34.05 +/-  0.84
# log(Z_1)   =          -34.14 +/-  0.85 (still evaluating)
# log(Z_2)   =          -36.95 +/-  1.01 (still evaluating)
# log(Z_3)   =          -38.79 +/-  1.27
#
#
#
# _____________________
# lives      | 28 |  4 |
# phantoms   |118 | 20 |
# posteriors |777 |728 |
# equals     |  6 |  4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 897
# nposterior =                 897
# nequals    =                  10
# nlike      =               15258
# <nlike>    =          27.28   (           5.46 per slice )
# log(Z)     =          -29.31 +/-  0.85
# log(Z_1)   =          -29.80 +/-  0.85 (still evaluating)
# log(Z_2)   =          -30.39 +/-  1.00 (still evaluating)
# log(Z_3)   =          -38.79 +/-  1.27
#
#
#
# ________________
# lives      | 32 |
# phantoms   |115 |
# posteriors |802 |
# equals     | 15 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                 928
# nposterior =                 928
# nequals    =                  10
# nlike      =               15997
# <nlike>    =          23.09   (           4.62 per slice )
# log(Z)     =          -27.40 +/-  0.84
# log(Z_1)   =          -27.67 +/-  0.85 (still evaluating)
# log(Z_2)   =          -28.98 +/-  0.99
# log(Z_3)   =          -38.79 +/-  1.27
#
#
#
# ________________
# lives      | 32 |
# phantoms   |120 |
# posteriors |835 |
# equals     | 28 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                 961
# nposterior =                 961
# nequals    =                  28
# nlike      =               16786
# <nlike>    =          24.66   (           4.93 per slice )
# log(Z)     =          -26.08 +/-  0.85
# log(Z_1)   =          -26.15 +/-  0.85 (still evaluating)
# log(Z_2)   =          -28.98 +/-  0.99
# log(Z_3)   =          -38.79 +/-  1.27
#
#
#
# ________________
# lives      | 32 |
# phantoms   |120 |
# posteriors |868 |
# equals     | 53 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                 994
# nposterior =                 994
# nequals    =                  57
# nlike      =               17595
# <nlike>    =          25.28   (           5.06 per slice )
# log(Z)     =          -25.41 +/-  0.85
# log(Z_1)   =          -25.44 +/-  0.85 (still evaluating)
# log(Z_2)   =          -28.98 +/-  0.99
# log(Z_3)   =          -38.79 +/-  1.27
#
#
#
# ________________
# lives      | 32 |
# phantoms   |125 |
# posteriors |901 |
# equals     | 80 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1027
# nposterior =                1027
# nequals    =                  85
# nlike      =               18371
# <nlike>    =          24.25   (           4.85 per slice )
# log(Z)     =          -25.02 +/-  0.86
# log(Z_1)   =          -25.05 +/-  0.86 (still evaluating)
# log(Z_2)   =          -28.98 +/-  0.99
# log(Z_3)   =          -38.79 +/-  1.27
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         1084                              |
# | log(Z) =          -24.68561 +/-            0.86339 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'polychord_output_directory/run1_model_3_w0_wa_-0.95_-0.1_wide_polychord_raw', with prefix 'run1_model_3_w0_wa_-0.95_-0.1_wide'
# [polychord] log(Z) = -24.8254 +/- 0.863394 ; Z in [6.9744841e-12, 3.9214519e-11] (68% C.L. log-gaussian)
# It took 5.5 hours to run
# [output] Output to be read-from/written-into folder 'polychord_output_directory', with prefix 'run1_model_3_w0_wa_-0.95_-0.1_narrow'
# [parameterization] *WARNING* There are repeated parameter labels: {'a_{s}': ['lnas', 'w0', 'wa']}
# [prior] *WARNING* External prior 'function' loaded. Mind that it might not be normalized!
# [likelihood_camb] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /Users/seanyi/Documents/polychord/PolyChordLite/build/lib.macosx-11.0-arm64-cpython-311/pypolychord
# [polychord] Storing raw PolyChord output in 'polychord_output_directory/run1_model_3_w0_wa_-0.95_-0.1_narrow_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {likelihood_CAMB: 1.1}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['omega_c', 'n_s', 'lnas', 'w0', 'wa']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      32
# nDims    :       5
# nDerived :       3
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to polychord_output_directory/run1_model_3_w0_wa_-0.95_-0.1_narrow_polychord_raw/run1_model_3_w0_wa_-0.95_-0.1_narrow.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            5
# started sampling
#
# ________________
# lives      | 32 |
# phantoms   |  4 |
# posteriors |289 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 289
# nposterior =                 289
# nequals    =                   1
# nlike      =                 334
# <nlike>    =           0.44   (           0.09 per slice )
# log(Z)     =       -39789.03 +/-  0.83
# log(Z_1)   =       -39789.03 +/-  0.83 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |105 |
# posteriors |322 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 322
# nposterior =                 322
# nequals    =                   1
# nlike      =                 818
# <nlike>    =          15.12   (           3.02 per slice )
# log(Z)     =       -21835.06 +/-  0.85
# log(Z_1)   =       -21835.06 +/-  0.85 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |112 |
# posteriors |355 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 355
# nposterior =                 355
# nequals    =                   1
# nlike      =                1408
# <nlike>    =          18.44   (           3.69 per slice )
# log(Z)     =        -9675.86 +/-  0.87
# log(Z_1)   =        -9675.86 +/-  0.87 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |133 |
# posteriors |388 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 388
# nposterior =                 388
# nequals    =                   1
# nlike      =                2046
# <nlike>    =          19.94   (           3.99 per slice )
# log(Z)     =        -4416.11 +/-  0.88
# log(Z_1)   =        -4416.11 +/-  0.88 (still evaluating)
#
#
#
# _____________________
# lives      | 12 | 20 |
# phantoms   | 65 | 98 |
# posteriors |403 |407 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 422
# nposterior =                 422
# nequals    =                   1
# nlike      =                2778
# <nlike>    =          22.88   (           4.58 per slice )
# log(Z)     =        -2294.05 +/-  0.90
# log(Z_1)   =        -2294.05 +/-  0.90 (still evaluating)
# log(Z_2)   =        -2403.35 +/-  0.91 (still evaluating)
#
#
#
# _____________________
# lives      |  8 | 24 |
# phantoms   | 61 |102 |
# posteriors |419 |426 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 457
# nposterior =                 457
# nequals    =                   1
# nlike      =                3589
# <nlike>    =          25.34   (           5.07 per slice )
# log(Z)     =        -1130.29 +/-  0.92
# log(Z_1)   =        -1130.29 +/-  0.92 (still evaluating)
# log(Z_2)   =        -1142.16 +/-  0.96 (still evaluating)
#
#
#
# __________________________
# lives      | 12 |  7 | 13 |
# phantoms   | 49 | 29 | 54 |
# posteriors |429 |439 |438 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 492
# nposterior =                 492
# nequals    =                   1
# nlike      =                4520
# <nlike>    =          29.09   (           5.82 per slice )
# log(Z)     =         -556.62 +/-  1.00
# log(Z_1)   =         -556.62 +/-  1.00 (still evaluating)
# log(Z_2)   =         -565.24 +/-  0.94 (still evaluating)
# log(Z_3)   =         -565.70 +/-  0.92 (still evaluating)
#
#
#
# __________________________
# lives      |  8 |  8 | 16 |
# phantoms   | 32 | 41 | 53 |
# posteriors |440 |448 |452 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 526
# nposterior =                 526
# nequals    =                   1
# nlike      =                5448
# <nlike>    =          29.00   (           5.80 per slice )
# log(Z)     =         -288.18 +/-  0.94
# log(Z_1)   =         -288.30 +/-  0.99 (still evaluating)
# log(Z_2)   =         -290.83 +/-  1.03 (still evaluating)
# log(Z_3)   =         -309.02 +/-  0.91 (still evaluating)
#
#
#
# __________________________
# lives      |  7 | 10 | 15 |
# phantoms   | 28 | 49 | 66 |
# posteriors |448 |457 |469 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 560
# nposterior =                 560
# nequals    =                   1
# nlike      =                6381
# <nlike>    =          29.16   (           5.83 per slice )
# log(Z)     =         -178.73 +/-  0.98
# log(Z_1)   =         -178.76 +/-  0.99 (still evaluating)
# log(Z_2)   =         -182.79 +/-  0.95 (still evaluating)
# log(Z_3)   =         -185.54 +/-  1.07 (still evaluating)
#
#
#
# _______________________________
# lives      |  6 | 20 |  5 |  1 |
# phantoms   | 39 | 77 | 25 | 10 |
# posteriors |470 |484 |455 |450 |
# equals     |  1 |  3 |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       4
# ndead      =                 597
# nposterior =                 597
# nequals    =                   2
# nlike      =                7388
# <nlike>    =          31.47   (           6.29 per slice )
# log(Z)     =         -106.46 +/-  0.98
# log(Z_1)   =         -106.48 +/-  0.99 (still evaluating)
# log(Z_2)   =         -110.75 +/-  0.83 (still evaluating)
# log(Z_3)   =         -113.14 +/-  1.00 (still evaluating)
# log(Z_4)   =         -123.86 +/-  1.08 (still evaluating)
#
#
#
# __________________________
# lives      |  2 | 24 |  6 |
# phantoms   | 10 | 80 | 19 |
# posteriors |478 |499 |462 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =                 628
# nposterior =                 628
# nequals    =                   2
# nlike      =                8237
# <nlike>    =          26.53   (           5.31 per slice )
# log(Z)     =          -71.30 +/-  1.00
# log(Z_1)   =          -71.48 +/-  1.06 (still evaluating)
# log(Z_2)   =          -74.05 +/-  1.17 (still evaluating)
# log(Z_3)   =          -75.01 +/-  1.19 (still evaluating)
# log(Z_4)   =          -98.47 +/-  1.08
#
#
#
# _____________________
# lives      | 23 |  9 |
# phantoms   |107 | 27 |
# posteriors |527 |465 |
# equals     |  3 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =                 661
# nposterior =                 661
# nequals    =                   5
# nlike      =                9085
# <nlike>    =          26.50   (           5.30 per slice )
# log(Z)     =          -48.63 +/-  0.75
# log(Z_1)   =          -48.87 +/-  0.80 (still evaluating)
# log(Z_2)   =          -50.81 +/-  1.24 (still evaluating)
# log(Z_3)   =          -66.28 +/-  1.11
# log(Z_4)   =          -98.47 +/-  1.08
#
#
#
# __________________________
# lives      |  4 |  5 | 23 |
# phantoms   | 18 | 28 |120 |
# posteriors |475 |529 |549 |
# equals     |  2 |  2 |  7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                 695
# nposterior =                 695
# nequals    =                   7
# nlike      =               10070
# <nlike>    =          30.78   (           6.16 per slice )
# log(Z)     =          -38.88 +/-  0.73
# log(Z_1)   =          -39.15 +/-  0.79 (still evaluating)
# log(Z_2)   =          -41.05 +/-  1.13 (still evaluating)
# log(Z_3)   =          -42.43 +/-  0.93 (still evaluating)
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# __________________________
# lives      |  4 |  2 | 26 |
# phantoms   | 14 | 24 |118 |
# posteriors |480 |536 |571 |
# equals     |  1 |  2 |  5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                 729
# nposterior =                 729
# nequals    =                   8
# nlike      =               11067
# <nlike>    =          31.16   (           6.23 per slice )
# log(Z)     =          -32.19 +/-  0.74
# log(Z_1)   =          -33.08 +/-  0.82 (still evaluating)
# log(Z_2)   =          -33.16 +/-  0.84 (still evaluating)
# log(Z_3)   =          -34.65 +/-  1.29 (still evaluating)
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# __________________________
# lives      |  1 |  5 | 26 |
# phantoms   |  5 | 31 |111 |
# posteriors |486 |540 |597 |
# equals     |  3 |  4 |  5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                 765
# nposterior =                 765
# nequals    =                  14
# nlike      =               12114
# <nlike>    =          32.72   (           6.54 per slice )
# log(Z)     =          -27.74 +/-  0.76
# log(Z_1)   =          -28.28 +/-  0.82 (still evaluating)
# log(Z_2)   =          -29.31 +/-  0.98 (still evaluating)
# log(Z_3)   =          -30.25 +/-  1.26 (still evaluating)
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# _____________________
# lives      |  3 | 29 |
# phantoms   | 29 |136 |
# posteriors |544 |623 |
# equals     |  5 | 17 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 796
# nposterior =                 796
# nequals    =                  14
# nlike      =               12965
# <nlike>    =          26.59   (           5.32 per slice )
# log(Z)     =          -24.93 +/-  0.77
# log(Z_1)   =          -25.25 +/-  0.81 (still evaluating)
# log(Z_2)   =          -27.04 +/-  0.98 (still evaluating)
# log(Z_3)   =          -27.90 +/-  1.41
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# ________________
# lives      | 32 |
# phantoms   |138 |
# posteriors |646 |
# equals     | 24 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                 825
# nposterior =                 825
# nequals    =                  17
# nlike      =               13731
# <nlike>    =          23.94   (           4.79 per slice )
# log(Z)     =          -23.49 +/-  0.80
# log(Z_1)   =          -23.87 +/-  0.82 (still evaluating)
# log(Z_2)   =          -24.98 +/-  1.05
# log(Z_3)   =          -27.90 +/-  1.41
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# ________________
# lives      | 32 |
# phantoms   |112 |
# posteriors |679 |
# equals     | 26 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                 858
# nposterior =                 858
# nequals    =                  33
# nlike      =               14570
# <nlike>    =          26.22   (           5.24 per slice )
# log(Z)     =          -22.39 +/-  0.81
# log(Z_1)   =          -22.51 +/-  0.83 (still evaluating)
# log(Z_2)   =          -24.98 +/-  1.05
# log(Z_3)   =          -27.90 +/-  1.41
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# ________________
# lives      | 32 |
# phantoms   |132 |
# posteriors |712 |
# equals     | 57 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                 891
# nposterior =                 891
# nequals    =                  61
# nlike      =               15370
# <nlike>    =          25.00   (           5.00 per slice )
# log(Z)     =          -21.70 +/-  0.82
# log(Z_1)   =          -21.76 +/-  0.83 (still evaluating)
# log(Z_2)   =          -24.98 +/-  1.05
# log(Z_3)   =          -27.90 +/-  1.41
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
# ________________
# lives      | 32 |
# phantoms   |144 |
# posteriors |745 |
# equals     | 80 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                 924
# nposterior =                 924
# nequals    =                  80
# nlike      =               16184
# <nlike>    =          25.44   (           5.09 per slice )
# log(Z)     =          -21.39 +/-  0.83
# log(Z_1)   =          -21.44 +/-  0.84 (still evaluating)
# log(Z_2)   =          -24.98 +/-  1.05
# log(Z_3)   =          -27.90 +/-  1.41
# log(Z_4)   =          -66.28 +/-  1.11
# log(Z_5)   =          -98.47 +/-  1.08
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =          968                              |
# | log(Z) =          -21.16205 +/-            0.83327 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'polychord_output_directory/run1_model_3_w0_wa_-0.95_-0.1_narrow_polychord_raw', with prefix 'run1_model_3_w0_wa_-0.95_-0.1_narrow'
# [polychord] log(Z) = -21.4099 +/- 0.833272 ; Z in [2.1873562e-10, 1.1579507e-09] (68% C.L. log-gaussian)
# It took 4.53 hours to run
# [output] Output to be read-from/written-into folder 'polychord_output_directory', with prefix 'run1_model_1_-0.95_-0.1'
# [likelihood_camb] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /Users/seanyi/Documents/polychord/PolyChordLite/build/lib.macosx-11.0-arm64-cpython-311/pypolychord
# [polychord] Storing raw PolyChord output in 'polychord_output_directory/run1_model_1_-0.95_-0.1_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {likelihood_CAMB: 1.8}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['omega_c', 'n_s', 'lnas']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      32
# nDims    :       3
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to polychord_output_directory/run1_model_1_-0.95_-0.1_polychord_raw/run1_model_1_-0.95_-0.1.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            5
# started sampling
#
# ________________
# lives      | 32 |
# phantoms   |  4 |
# posteriors |289 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 289
# nposterior =                 289
# nequals    =                   1
# nlike      =                 342
# <nlike>    =           0.69   (           0.14 per slice )
# log(Z)     =       -32195.64 +/-  0.83
# log(Z_1)   =       -32195.64 +/-  0.83 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   | 79 |
# posteriors |322 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 322
# nposterior =                 322
# nequals    =                   1
# nlike      =                 880
# <nlike>    =          16.81   (           3.36 per slice )
# log(Z)     =       -12317.16 +/-  0.85
# log(Z_1)   =       -12317.16 +/-  0.85 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |109 |
# posteriors |355 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 355
# nposterior =                 355
# nequals    =                   1
# nlike      =                1499
# <nlike>    =          19.34   (           3.87 per slice )
# log(Z)     =        -5030.28 +/-  0.87
# log(Z_1)   =        -5030.28 +/-  0.87 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |118 |
# posteriors |388 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 388
# nposterior =                 388
# nequals    =                   1
# nlike      =                2119
# <nlike>    =          19.38   (           3.88 per slice )
# log(Z)     =        -2365.32 +/-  0.88
# log(Z_1)   =        -2365.32 +/-  0.88 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |117 |
# posteriors |421 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 421
# nposterior =                 421
# nequals    =                   1
# nlike      =                2831
# <nlike>    =          22.25   (           4.45 per slice )
# log(Z)     =        -1162.08 +/-  0.90
# log(Z_1)   =        -1162.08 +/-  0.90 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |125 |
# posteriors |454 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 454
# nposterior =                 454
# nequals    =                   1
# nlike      =                3595
# <nlike>    =          23.88   (           4.78 per slice )
# log(Z)     =         -541.66 +/-  0.92
# log(Z_1)   =         -541.66 +/-  0.92 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |143 |
# posteriors |487 |
# equals     |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 487
# nposterior =                 487
# nequals    =                   1
# nlike      =                4379
# <nlike>    =          24.50   (           4.90 per slice )
# log(Z)     =         -298.95 +/-  0.86
# log(Z_1)   =         -298.95 +/-  0.86 (still evaluating)
#
#
#
# _____________________
# lives      | 23 |  9 |
# phantoms   |128 | 43 |
# posteriors |508 |500 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 521
# nposterior =                 521
# nequals    =                   2
# nlike      =                5700
# <nlike>    =          41.28   (           8.26 per slice )
# log(Z)     =         -150.34 +/-  0.76
# log(Z_1)   =         -151.09 +/-  0.91 (still evaluating)
# log(Z_2)   =         -151.26 +/-  0.93 (still evaluating)
#
#
#
# _____________________
# lives      | 27 |  5 |
# phantoms   |112 | 24 |
# posteriors |527 |515 |
# equals     |  1 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 555
# nposterior =                 555
# nequals    =                   1
# nlike      =                6834
# <nlike>    =          35.44   (           7.09 per slice )
# log(Z)     =          -78.41 +/-  0.85
# log(Z_1)   =          -78.41 +/-  0.85 (still evaluating)
# log(Z_2)   =          -85.60 +/-  0.84 (still evaluating)
#
#
#
# _____________________
# lives      | 31 |  1 |
# phantoms   |134 |  7 |
# posteriors |555 |520 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 588
# nposterior =                 588
# nequals    =                   2
# nlike      =                7776
# <nlike>    =          29.44   (           5.89 per slice )
# log(Z)     =          -51.22 +/-  0.70
# log(Z_1)   =          -51.43 +/-  0.74 (still evaluating)
# log(Z_2)   =          -53.33 +/-  1.07 (still evaluating)
#
#
#
# _____________________
# lives      | 30 |  2 |
# phantoms   |108 | 20 |
# posteriors |594 |520 |
# equals     |  8 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 627
# nposterior =                 627
# nequals    =                   9
# nlike      =                8974
# <nlike>    =          37.44   (           7.49 per slice )
# log(Z)     =          -29.73 +/-  0.64
# log(Z_1)   =          -29.73 +/-  0.64 (still evaluating)
# log(Z_2)   =          -53.33 +/-  1.07 (still evaluating)
#
#
#
# _____________________
# lives      | 31 |  1 |
# phantoms   |119 | 30 |
# posteriors |628 |522 |
# equals     |  4 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 663
# nposterior =                 663
# nequals    =                   1
# nlike      =               10302
# <nlike>    =          41.50   (           8.30 per slice )
# log(Z)     =          -23.29 +/-  0.90
# log(Z_1)   =          -24.09 +/-  1.17 (still evaluating)
# log(Z_2)   =          -24.01 +/-  0.67 (still evaluating)
#
#
#
# _____________________
# lives      | 31 |  1 |
# phantoms   |128 | 16 |
# posteriors |643 |631 |
# equals     |  7 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 682
# nposterior =                 682
# nequals    =                   5
# nlike      =               11261
# <nlike>    =          29.97   (           5.99 per slice )
# log(Z)     =          -21.02 +/-  0.74
# log(Z_1)   =          -21.69 +/-  0.66 (still evaluating)
# log(Z_2)   =          -22.21 +/-  1.11
# log(Z_3)   =          -23.46 +/-  0.75 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |148 |
# posteriors |672 |
# equals     | 23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                 712
# nposterior =                 712
# nequals    =                  23
# nlike      =               11991
# <nlike>    =          22.81   (           4.56 per slice )
# log(Z)     =          -19.23 +/-  0.63
# log(Z_1)   =          -19.38 +/-  0.65 (still evaluating)
# log(Z_2)   =          -22.21 +/-  1.11
# log(Z_3)   =          -22.42 +/-  0.80
#
#
#
# ________________
# lives      | 32 |
# phantoms   |131 |
# posteriors |705 |
# equals     | 40 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                 745
# nposterior =                 745
# nequals    =                  53
# nlike      =               12755
# <nlike>    =          23.88   (           4.78 per slice )
# log(Z)     =          -18.23 +/-  0.64
# log(Z_1)   =          -18.28 +/-  0.65 (still evaluating)
# log(Z_2)   =          -22.21 +/-  1.11
# log(Z_3)   =          -22.42 +/-  0.80
#
#
#
# ________________
# lives      | 32 |
# phantoms   |132 |
# posteriors |738 |
# equals     | 70 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                 778
# nposterior =                 778
# nequals    =                  83
# nlike      =               13535
# <nlike>    =          24.38   (           4.88 per slice )
# log(Z)     =          -17.79 +/-  0.64
# log(Z_1)   =          -17.82 +/-  0.65 (still evaluating)
# log(Z_2)   =          -22.21 +/-  1.11
# log(Z_3)   =          -22.42 +/-  0.80
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =          833                              |
# | log(Z) =          -17.46522 +/-            0.65138 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'polychord_output_directory/run1_model_1_-0.95_-0.1_polychord_raw', with prefix 'run1_model_1_-0.95_-0.1'
# [polychord] log(Z) = -17.4652 +/- 0.651375 ; Z in [1.3553883e-08, 4.987021e-08] (68% C.L. log-gaussian)
# It took 2.44 hours to run
