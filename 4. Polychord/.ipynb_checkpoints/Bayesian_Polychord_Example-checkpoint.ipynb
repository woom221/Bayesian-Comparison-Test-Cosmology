# %% [markdown]
# ## Polychord Example Run
#
# The details can be found from Bayesian_Polychord.ipynb located at the same folder.
#
# This is an example run used to gather information for model 1 and model 3.

# %%
from cobaya.run import run
import healpy as hp
import pyccl as ccl

import numpy as np
import matplotlib.pyplot as plt
import itertools
import time
import os

# %%
def create_bin(min_ell, max_ell, n, cgg, ckg, ckk):
    x = np.arange(min_ell, max_ell, 1)
    bin_edges = np.linspace(np.min(x), np.max(x), n)
    bin_centers, galaxy_galaxy_bin = bin_mat(x, np.array(cgg), bin_edges)
    _, lensing_galaxy_bin = bin_mat(x, np.array(ckg), bin_edges)
    _, lensing_lensing_bin = bin_mat(x, np.array(ckk), bin_edges)
    return bin_centers, galaxy_galaxy_bin, lensing_galaxy_bin,lensing_lensing_bin

def bin_mat(r=[],mat=[],r_bins=[]):
    bin_center=0.5*(r_bins[1:]+r_bins[:-1])
    n_bins=len(bin_center)
    ndim=len(mat.shape)
    mat_int=np.zeros([n_bins]*ndim,dtype='float64')
    norm_int=np.zeros([n_bins]*ndim,dtype='float64')
    bin_idx=np.digitize(r,r_bins)-1
    r2=np.sort(np.unique(np.append(r,r_bins))) #this takes care of problems around bin edges
    dr=np.gradient(r2)
    r2_idx=[i for i in np.arange(len(r2)) if r2[i] in r]
    dr=dr[r2_idx]
    r_dr=r*dr

    ls=['i','j','k','l']
    s1=ls[0]
    s2=ls[0]
    r_dr_m=r_dr
    for i in np.arange(ndim-1):
        s1=s2+','+ls[i+1]
        s2+=ls[i+1]
        r_dr_m=np.einsum(s1+'->'+s2,r_dr_m,r_dr)#works ok for 2-d case

    mat_r_dr=mat*r_dr_m
    for indxs in itertools.product(np.arange(min(bin_idx),n_bins),repeat=ndim):
        # x={} #np.zeros_like(mat_r_dr,dtype='bool')
        norm_ijk=1
        mat_t=[]
        for nd in np.arange(ndim):
            slc = [slice(None)] * (ndim)
            #x[nd]=bin_idx==indxs[nd]
            slc[nd]=bin_idx==indxs[nd]
            if nd==0:
                mat_t=mat_r_dr[slc[0]]
            else:
                mat_t=mat_t[slc[0]]
            norm_ijk*=np.sum(r_dr[slc[nd]])
        if norm_ijk==0:
            continue
        mat_int[indxs]=np.sum(mat_t)/norm_ijk
        norm_int[indxs]=norm_ijk
    return bin_center,mat_int

def default_nz(z):
    return np.exp(-0.5 * ((z - 0.5) / 0.1) ** 2)

def default_b1(z):
    return np.ones_like(z)

class CosmologicalModel_lambda_CDM:
    def __init__(self, z_min=0, z_max=1, z_step=256, max_ell=1000, omega_c=0.25, omega_b=0.05,
                 h=0.67, a_s=2.1e-9, n_s=0.96, m_nu=0.06):
        self.z_min = z_min
        self.z_max = z_max
        self.z_step = z_step
        self.max_ell = max_ell
        self.z = np.linspace(self.z_min, self.z_max, self.z_step)
        self.omega_c = omega_c
        self.omega_b = omega_b
        self.h = h
        self.a_s = a_s
        self.n_s = n_s
        self.m_nu = m_nu
        self.ells = np.arange(0, self.max_ell, 1)
        self.model = ccl.Cosmology(Omega_c=omega_c, Omega_b=omega_b, h=h, A_s=a_s, 
                                   n_s=n_s, m_nu=m_nu, mass_split="single", 
                                   transfer_function="boltzmann_camb")

    def generate_galaxy_clustering(self, nz_fn=default_nz, b1_fn=default_b1):
        nz = nz_fn(self.z)
        b1 = b1_fn(self.z)
        return ccl.NumberCountsTracer(self.model, has_rsd=False, dndz=(self.z, nz), bias=(self.z, b1))

    def generate_lensing(self, z_source=1100):
        return ccl.CMBLensingTracer(self.model, z_source=z_source)

    def generate_angular_ps(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, output_type="all", is_plot=True):
        galaxy_dist = self.generate_galaxy_clustering(nz_fn, b1_fn)
        lensing_dist = self.generate_lensing(z_source=z_source)
        cgg = ccl.angular_cl(self.model, galaxy_dist, galaxy_dist, self.ells)
        ckk = ccl.angular_cl(self.model, lensing_dist, lensing_dist, self.ells)
        ckg = ccl.angular_cl(self.model, lensing_dist, galaxy_dist, self.ells)
        if output_type == "cgg":
            if is_plot:
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return cgg
        elif output_type == "ckg":
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckg
        elif output_type == "ckk":
            if is_plot:
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckk
        else:
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.legend(loc="best")
                plt.show()
            return cgg, ckg, ckk

    def generate_survey_map(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, nside=1024, pol=False, is_plot=True):
        np.random.seed(998905029)
        cl = self.generate_angular_ps(nz_fn=nz_fn, b1_fn=b1_fn, z_source=z_source, is_plot=False)
        delta_g, delta_k = hp.synfast(list(cl), nside=nside, pol=pol)
        if is_plot:
            hp.mollview(delta_g, cmap='seismic', min=-.1, max=.1, title="Galaxy Overdensity Field")
            hp.mollview(delta_k, cmap='seismic', min=-.1, max=.1, title="Lensing Overdensity Field")
            plt.show()
        return delta_g, delta_k
    
class CosmologicalModel_w_CDM:
    def __init__(self, z_min=0, z_max=1, z_step=256, max_ell=1000, omega_c=0.25, omega_b=0.05,
                 h=0.67, a_s=2.1e-9, n_s=0.96, m_nu=0.06, w0=-1, wa=0):
        self.z_min = z_min
        self.z_max = z_max
        self.z_step = z_step
        self.max_ell = max_ell
        self.z = np.linspace(self.z_min, self.z_max, self.z_step)
        self.omega_c = omega_c
        self.omega_b = omega_b
        self.h = h
        self.a_s = a_s
        self.n_s = n_s
        self.m_nu = m_nu
        self.w0 = w0
        self.wa = wa
        self.ells = np.arange(0, self.max_ell, 1)
        self.model = ccl.Cosmology(Omega_c=omega_c, Omega_b=omega_b, h=h, A_s=a_s, 
                                   n_s=n_s, m_nu=m_nu, w0=w0, wa=wa, mass_split="single", 
                                   transfer_function="boltzmann_camb", 
                                   extra_parameters={"camb": {"dark_energy_model": "ppf"}})

    def generate_galaxy_clustering(self, nz_fn=default_nz, b1_fn=default_b1):
        nz = nz_fn(self.z)
        b1 = b1_fn(self.z)
        return ccl.NumberCountsTracer(self.model, has_rsd=False, dndz=(self.z, nz), bias=(self.z, b1))

    def generate_lensing(self, z_source=1100):
        return ccl.CMBLensingTracer(self.model, z_source=z_source)

    def generate_angular_ps(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, output_type="all", is_plot=True):
        galaxy_dist = self.generate_galaxy_clustering(nz_fn, b1_fn)
        lensing_dist = self.generate_lensing(z_source=z_source)
        cgg = ccl.angular_cl(self.model, galaxy_dist, galaxy_dist, self.ells)
        ckk = ccl.angular_cl(self.model, lensing_dist, lensing_dist, self.ells)
        ckg = ccl.angular_cl(self.model, lensing_dist, galaxy_dist, self.ells)
        if output_type == "cgg":
            if is_plot:
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return cgg
        elif output_type == "ckg":
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckg
        elif output_type == "ckk":
            if is_plot:
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.show()
            return ckk
        else:
            if is_plot:
                plt.loglog(self.ells, ckg, label="Lensing-Galaxy")
                plt.loglog(self.ells, cgg, label="Galaxy-Galaxy")
                plt.loglog(self.ells, ckk, label="Lensing-Lensing")
                plt.xlabel("Angular Scale")
                plt.ylabel("Spectrum Density")
                plt.legend(loc="best")
                plt.show()
            return cgg, ckg, ckk

    def generate_survey_map(self, nz_fn=default_nz, b1_fn=default_b1, z_source=1100, nside=1024, pol=False, is_plot=True):
        np.random.seed(998905029)
        cl = self.generate_angular_ps(nz_fn=nz_fn, b1_fn=b1_fn, z_source=z_source, is_plot=False)
        delta_g, delta_k = hp.synfast(list(cl), nside=nside, pol=pol)
        if is_plot:
            hp.mollview(delta_g, cmap='seismic', min=-.1, max=.1, title="Galaxy Overdensity Field")
            hp.mollview(delta_k, cmap='seismic', min=-.1, max=.1, title="Lensing Overdensity Field")
            plt.show()
        return delta_g, delta_k
    

max_ell = 1000
min_ell = 75
n = 10

stacked_ps = np.load("Data/Model_1_Model_3_Comparison/stacked_ps_5_param__w0_wa_-0.9_-0.2_1_3.npy", allow_pickle=True)
cov = np.load("Data/Model_1_Model_3_Comparison/cov_5_param__w0_wa_-0.9_-0.2_1_3.npy", allow_pickle=True)

def generate_power_spectra_model_1(omega_c, n_s, lnas):
    m_nu = 0.06
    h = 0.6766
    omega_b = 0.02218 / (h**2)
    a_s = np.exp(lnas) / (10**10)
    model = CosmologicalModel_lambda_CDM(h=h, omega_b=omega_b, omega_c=omega_c, n_s=n_s, a_s=a_s, m_nu=m_nu, max_ell=max_ell)
    cgg, ckg, ckk = model.generate_angular_ps(is_plot=False)
    _, cgg_bins, ckg_bins, ckk_bins = create_bin(min_ell, max_ell, n + 1, cgg[min_ell:], ckg[min_ell:], ckk[min_ell:])
    return np.hstack((cgg_bins, ckg_bins, ckk_bins)).flatten()

def generate_power_spectra_model_2(omega_c, n_s, lnas, m_nu):
    h = 0.6766
    omega_b = 0.02218 / (h**2)
    a_s = np.exp(lnas) / (10**10)
    model = CosmologicalModel_lambda_CDM(h=h, omega_b=omega_b, omega_c=omega_c, n_s=n_s, a_s=a_s, m_nu=m_nu, max_ell=max_ell)
    cgg, ckg, ckk = model.generate_angular_ps(is_plot=False)
    _, cgg_bins, ckg_bins, ckk_bins = create_bin(min_ell, max_ell, n + 1, cgg[min_ell:], ckg[min_ell:], ckk[min_ell:])
    return np.hstack((cgg_bins, ckg_bins, ckk_bins)).flatten()

def generate_power_spectra_model_3(omega_c, n_s, lnas, w0, wa):
    m_nu = 0.06
    h = 0.6766
    omega_b = 0.02218 / (h**2)
    a_s = np.exp(lnas) / (10**10)
    model = CosmologicalModel_w_CDM(h=h, omega_b=omega_b, omega_c=omega_c, n_s=n_s, a_s=a_s, m_nu=m_nu, w0=w0, wa=wa, max_ell=max_ell)
    cgg, ckg, ckk = model.generate_angular_ps(is_plot=False)
    _, cgg_bins, ckg_bins, ckk_bins = create_bin(min_ell, max_ell, n + 1, cgg[min_ell:], ckg[min_ell:], ckk[min_ell:])
    return np.hstack((cgg_bins, ckg_bins, ckk_bins)).flatten()

def log_likelihood_model_1(omega_c, n_s, lnas):
    mu = generate_power_spectra_model_1(omega_c, n_s, lnas)
    diff = stacked_ps - mu
    return -0.5 * np.dot(diff, np.dot(np.linalg.inv(cov), diff.T)).item()


def log_likelihood_model_2(omega_c, n_s, lnas, m_nu):
    mu = generate_power_spectra_model_2(omega_c, n_s, lnas, m_nu)
    diff = stacked_ps - mu
    return -0.5 * np.dot(diff, np.dot(np.linalg.inv(cov), diff.T)).item()

def log_likelihood_model_3(omega_c, n_s, lnas, w0, wa):
    mu = generate_power_spectra_model_3(omega_c, n_s, lnas, w0, wa)
    diff = stacked_ps - mu
    return -0.5 * np.dot(diff, np.dot(np.linalg.inv(cov), diff.T)).item()

def get_unique_run_number(base_name):
    run_number = 1
    while os.path.exists(f"{base_name}" + f"{run_number}" + "_model_2" + ".logZ"):
        run_number += 1
    return run_number

def prior_w0_wa(w0, wa):
    if w0 + wa >= 0:
        return -np.inf 
    else:
        return 0 
    
# function to run PolyChord and return log-evidence
def run_polychord(info):
    start_time = time.time()
    results = run(info)
    end_time = time.time()
    print(f"It took {round((end_time - start_time)/3600, 2)} hours to run")
    return results

def main():
  # base output directory
  output_base = "polychord_output_directory/run"
  run_number = get_unique_run_number(output_base)

  # configuration for Model 1 (lambda CDM)
  info_model_1 = {
      "likelihood": {
          "likelihood_CAMB": log_likelihood_model_1
      },
      "params": {
          "omega_c": {"prior": {"min": 0.1, "max": 0.9}, "latex": r"\Omega_{c}"},
          "n_s": {"prior": {"min": 0.8, "max": 1.2}, "latex": r"n_{s}"},
          "lnas": {"prior": {"min": 1.61, "max": 3.91}, "latex": r"a_{s}"}
      },
      "sampler": {
          "polychord": {
              "path": "/Users/seanyi/Documents/polychord/PolyChordLite",
              "nlive": 32,
              "num_repeats": 5,
              "precision_criterion": 0.2
          }
      },
      "output": f"{output_base}{run_number}_model_1_-0.9_-0.2",
  }

  # configuration for Model 2 (varying neutrino mass)
  info_model_3_wide = {
      "likelihood": {
          "likelihood_CAMB": log_likelihood_model_3
      },
      "params": {
          "omega_c": {"prior": {"min": 0.1, "max": 0.9}, "latex": r"\Omega_{c}"},
          "n_s": {"prior": {"min": 0.8, "max": 1.2}, "latex": r"n_{s}"},
          "lnas": {"prior": {"min": 1.61, "max": 3.91}, "latex": r"a_{s}"},
          "w0": {"prior": {"min": -5, "max": 1}, "latex": r"a_{s}"},
          "wa": {"prior": {"min": -5, "max": 2}, "latex": r"a_{s}"}
      },
      "prior": {"function": prior_w0_wa},
      "sampler": {
          "polychord": {
              "path": "/Users/seanyi/Documents/polychord/PolyChordLite",
              "nlive": 32,
              "num_repeats": 5,
              "precision_criterion": 0.2
          }
      },
      "output": f"{output_base}{run_number}_model_3_w0_wa_-0.9_-0.2_wide",
  }

  info_model_3_narrow = {
      "likelihood": {
          "likelihood_CAMB": log_likelihood_model_3
      },
      "params": {
          "omega_c": {"prior": {"min": 0.1, "max": 0.9}, "latex": r"\Omega_{c}"},
          "n_s": {"prior": {"min": 0.8, "max": 1.2}, "latex": r"n_{s}"},
          "lnas": {"prior": {"min": 1.61, "max": 3.91}, "latex": r"a_{s}"},
          "w0": {"prior": {"min": -3, "max": 1}, "latex": r"a_{s}"},
          "wa": {"prior": {"min": -3, "max": 2}, "latex": r"a_{s}"}
      },
      "prior": {"function": prior_w0_wa},
      "sampler": {
          "polychord": {
              "path": "/Users/seanyi/Documents/polychord/PolyChordLite",
              "nlive": 32,
              "num_repeats": 5,
              "precision_criterion": 0.2
          }
      },
      "output": f"{output_base}{run_number}_model_3_w0_wa_-0.9_-0.2_narrow",
  }

  # run PolyChord for Model 3
  run_polychord(info_model_3_wide)
  run_polychord(info_model_3_narrow)

  # run PolyChord for Model 1
  run_polychord(info_model_1)

# %%
main()
# Out:
# [output] Output to be read-from/written-into folder 'polychord_output_directory', with prefix 'run1_model_3_w0_wa_-0.9_-0.2_wide'
# [parameterization] *WARNING* There are repeated parameter labels: {'a_{s}': ['lnas', 'w0', 'wa']}
# [prior] *WARNING* External prior 'function' loaded. Mind that it might not be normalized!
# [likelihood_camb] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /Users/seanyi/Documents/polychord/PolyChordLite/build/lib.macosx-11.0-arm64-cpython-311/pypolychord
# [polychord] Storing raw PolyChord output in 'polychord_output_directory/run1_model_3_w0_wa_-0.9_-0.2_wide_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [Seans-MacBook-Pro-3.local:73763] shmem: mmap: an error occurred while determining whether or not /var/folders/w1/36c6k6fx2bx5_d7s_9z_nnhr0000gn/T//ompi.Seans-MacBook-Pro-3.501/jf.0/3317825536/sm_segment.Seans-MacBook-Pro-3.501.c5c20000.0 could be created.
# [model] Setting measured speeds (per sec): {likelihood_CAMB: 0.894}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['omega_c', 'n_s', 'lnas', 'w0', 'wa']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      32
# nDims    :       5
# nDerived :       3
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to polychord_output_directory/run1_model_3_w0_wa_-0.9_-0.2_wide_polychord_raw/run1_model_3_w0_wa_-0.9_-0.2_wide.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            5
# started sampling
#
# ________________
# lives      | 32 |
# phantoms   |  4 |
# posteriors |289 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 289
# nposterior =                 289
# nequals    =                   1
# nlike      =                 329
# <nlike>    =           0.28   (           0.06 per slice )
# log(Z)     =       -48795.39 +/-  0.83
# log(Z_1)   =       -48795.39 +/-  0.83 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |100 |
# posteriors |322 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 322
# nposterior =                 322
# nequals    =                   1
# nlike      =                 814
# <nlike>    =          15.16   (           3.03 per slice )
# log(Z)     =       -25115.74 +/-  0.85
# log(Z_1)   =       -25115.74 +/-  0.85 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |114 |
# posteriors |355 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 355
# nposterior =                 355
# nequals    =                   1
# nlike      =                1364
# <nlike>    =          17.19   (           3.44 per slice )
# log(Z)     =       -10837.11 +/-  0.87
# log(Z_1)   =       -10837.11 +/-  0.87 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |122 |
# posteriors |388 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 388
# nposterior =                 388
# nequals    =                   1
# nlike      =                1929
# <nlike>    =          17.66   (           3.53 per slice )
# log(Z)     =        -6354.17 +/-  0.88
# log(Z_1)   =        -6354.17 +/-  0.88 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |100 |
# posteriors |421 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 421
# nposterior =                 421
# nequals    =                   1
# nlike      =                2535
# <nlike>    =          18.94   (           3.79 per slice )
# log(Z)     =        -2765.87 +/-  0.90
# log(Z_1)   =        -2765.87 +/-  0.90 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |133 |
# posteriors |454 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 454
# nposterior =                 454
# nequals    =                   1
# nlike      =                3311
# <nlike>    =          24.25   (           4.85 per slice )
# log(Z)     =        -1872.32 +/-  0.91
# log(Z_1)   =        -1872.32 +/-  0.91 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |134 |
# posteriors |487 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 487
# nposterior =                 487
# nequals    =                   1
# nlike      =                4048
# <nlike>    =          23.03   (           4.61 per slice )
# log(Z)     =        -1160.58 +/-  0.93
# log(Z_1)   =        -1160.58 +/-  0.93 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |139 |
# posteriors |520 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 520
# nposterior =                 520
# nequals    =                   1
# nlike      =                4836
# <nlike>    =          24.62   (           4.92 per slice )
# log(Z)     =         -811.47 +/-  0.95
# log(Z_1)   =         -811.47 +/-  0.95 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |154 |
# posteriors |553 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 553
# nposterior =                 553
# nequals    =                   1
# nlike      =                5769
# <nlike>    =          29.16   (           5.83 per slice )
# log(Z)     =         -529.30 +/-  0.96
# log(Z_1)   =         -529.30 +/-  0.96 (still evaluating)
#
#
#
# __________________________
# lives      | 21 |  4 |  7 |
# phantoms   |105 | 32 | 27 |
# posteriors |568 |565 |559 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 586
# nposterior =                 586
# nequals    =                   2
# nlike      =                6809
# <nlike>    =          32.50   (           6.50 per slice )
# log(Z)     =         -381.14 +/-  0.81
# log(Z_1)   =         -381.14 +/-  0.81 (still evaluating)
# log(Z_2)   =         -395.71 +/-  1.01 (still evaluating)
# log(Z_3)   =         -398.92 +/-  0.99 (still evaluating)
#
#
#
# __________________________
# lives      | 24 |  6 |  2 |
# phantoms   |105 | 29 |  4 |
# posteriors |591 |569 |570 |
# equals     |  2 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 624
# nposterior =                 624
# nequals    =                   1
# nlike      =                7857
# <nlike>    =          32.75   (           6.55 per slice )
# log(Z)     =         -215.05 +/-  1.05
# log(Z_1)   =         -215.13 +/-  1.07 (still evaluating)
# log(Z_2)   =         -218.40 +/-  0.80 (still evaluating)
# log(Z_3)   =         -219.15 +/-  1.13 (still evaluating)
#
#
#
# _____________________
# lives      | 23 |  9 |
# phantoms   | 99 | 41 |
# posteriors |616 |576 |
# equals     |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 660
# nposterior =                 660
# nequals    =                   3
# nlike      =                8984
# <nlike>    =          35.22   (           7.04 per slice )
# log(Z)     =         -153.60 +/-  0.81
# log(Z_1)   =         -153.97 +/-  0.85 (still evaluating)
# log(Z_2)   =         -155.23 +/-  1.21
# log(Z_3)   =         -161.61 +/-  1.07 (still evaluating)
#
#
#
# _____________________
# lives      | 28 |  4 |
# phantoms   |104 | 30 |
# posteriors |636 |589 |
# equals     |  3 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 693
# nposterior =                 693
# nequals    =                   2
# nlike      =                9909
# <nlike>    =          28.91   (           5.78 per slice )
# log(Z)     =         -112.52 +/-  0.93
# log(Z_1)   =         -112.71 +/-  0.99 (still evaluating)
# log(Z_2)   =         -114.57 +/-  0.88 (still evaluating)
# log(Z_3)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      | 26 |  6 |
# phantoms   | 73 | 35 |
# posteriors |662 |596 |
# equals     |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 726
# nposterior =                 726
# nequals    =                   3
# nlike      =               10793
# <nlike>    =          27.62   (           5.53 per slice )
# log(Z)     =          -83.24 +/-  0.83
# log(Z_1)   =          -83.66 +/-  0.87 (still evaluating)
# log(Z_2)   =          -84.77 +/-  1.21 (still evaluating)
# log(Z_3)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      | 18 | 14 |
# phantoms   | 64 | 57 |
# posteriors |693 |598 |
# equals     |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 759
# nposterior =                 759
# nequals    =                   1
# nlike      =               11651
# <nlike>    =          26.81   (           5.36 per slice )
# log(Z)     =          -67.43 +/-  0.88
# log(Z_1)   =          -67.43 +/-  0.88 (still evaluating)
# log(Z_2)   =          -75.11 +/-  1.28 (still evaluating)
# log(Z_3)   =         -155.23 +/-  1.21
#
#
#
# __________________________
# lives      | 15 | 11 |  6 |
# phantoms   | 73 | 53 | 35 |
# posteriors |721 |604 |601 |
# equals     |  3 |  3 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =                 796
# nposterior =                 796
# nequals    =                   6
# nlike      =               12781
# <nlike>    =          35.31   (           7.06 per slice )
# log(Z)     =          -54.64 +/-  0.82
# log(Z_1)   =          -54.67 +/-  0.83 (still evaluating)
# log(Z_2)   =          -59.20 +/-  1.13 (still evaluating)
# log(Z_3)   =          -60.41 +/-  1.18 (still evaluating)
# log(Z_4)   =         -155.23 +/-  1.21
#
#
#
# __________________________
# lives      | 18 | 11 |  3 |
# phantoms   | 66 | 62 | 16 |
# posteriors |614 |609 |732 |
# equals     |  3 |  2 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                 830
# nposterior =                 830
# nequals    =                   3
# nlike      =               13933
# <nlike>    =          36.00   (           7.20 per slice )
# log(Z)     =          -41.55 +/-  0.93
# log(Z_1)   =          -42.39 +/-  1.16 (still evaluating)
# log(Z_2)   =          -42.61 +/-  1.02 (still evaluating)
# log(Z_3)   =          -44.52 +/-  1.20 (still evaluating)
# log(Z_4)   =          -46.42 +/-  0.95
# log(Z_5)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      | 17 | 15 |
# phantoms   | 70 | 69 |
# posteriors |630 |621 |
# equals     |  5 |  5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 863
# nposterior =                 863
# nequals    =                   8
# nlike      =               14965
# <nlike>    =          32.25   (           6.45 per slice )
# log(Z)     =          -35.10 +/-  1.07
# log(Z_1)   =          -35.47 +/-  1.12 (still evaluating)
# log(Z_2)   =          -36.65 +/-  1.16 (still evaluating)
# log(Z_3)   =          -38.48 +/-  1.09
# log(Z_4)   =          -46.42 +/-  0.95
# log(Z_5)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      | 19 | 13 |
# phantoms   | 82 | 26 |
# posteriors |651 |635 |
# equals     |  9 |  4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 898
# nposterior =                 898
# nequals    =                  13
# nlike      =               15904
# <nlike>    =          29.34   (           5.87 per slice )
# log(Z)     =          -30.14 +/-  1.09
# log(Z_1)   =          -30.34 +/-  1.11 (still evaluating)
# log(Z_2)   =          -32.10 +/-  1.19 (still evaluating)
# log(Z_3)   =          -38.48 +/-  1.09
# log(Z_4)   =          -46.42 +/-  0.95
# log(Z_5)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      | 28 |  4 |
# phantoms   |113 | 18 |
# posteriors |672 |649 |
# equals     | 18 |  5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 933
# nposterior =                 933
# nequals    =                  22
# nlike      =               16882
# <nlike>    =          30.56   (           6.11 per slice )
# log(Z)     =          -28.20 +/-  1.08
# log(Z_1)   =          -28.61 +/-  1.11 (still evaluating)
# log(Z_2)   =          -29.48 +/-  1.19 (still evaluating)
# log(Z_3)   =          -38.48 +/-  1.09
# log(Z_4)   =          -46.42 +/-  0.95
# log(Z_5)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      | 27 |  5 |
# phantoms   |125 | 28 |
# posteriors |706 |651 |
# equals     | 35 |  7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 969
# nposterior =                 969
# nequals    =                  39
# nlike      =               17831
# <nlike>    =          29.66   (           5.93 per slice )
# log(Z)     =          -27.02 +/-  1.10
# log(Z_1)   =          -27.17 +/-  1.11 (still evaluating)
# log(Z_2)   =          -29.20 +/-  1.19 (still evaluating)
# log(Z_3)   =          -38.48 +/-  1.09
# log(Z_4)   =          -46.42 +/-  0.95
# log(Z_5)   =         -155.23 +/-  1.21
#
#
#
# __________________________
# lives      |  7 | 24 |  1 |
# phantoms   | 31 |102 | 19 |
# posteriors |661 |728 |710 |
# equals     |  7 | 54 | 31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       6
# ndead      =                1005
# nposterior =                1005
# nequals    =                  49
# nlike      =               19097
# <nlike>    =          39.56   (           7.91 per slice )
# log(Z)     =          -26.26 +/-  1.09
# log(Z_1)   =          -26.72 +/-  1.12 (still evaluating)
# log(Z_2)   =          -27.92 +/-  1.25 (still evaluating)
# log(Z_3)   =          -28.40 +/-  1.14 (still evaluating)
# log(Z_4)   =          -38.48 +/-  1.09
# log(Z_5)   =          -46.42 +/-  0.95
# log(Z_6)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      |  4 | 28 |
# phantoms   | 28 | 77 |
# posteriors |669 |749 |
# equals     | 14 | 68 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       6
# ndead      =                1036
# nposterior =                1036
# nequals    =                  27
# nlike      =               20283
# <nlike>    =          37.06   (           7.41 per slice )
# log(Z)     =          -25.87 +/-  1.10
# log(Z_1)   =          -26.36 +/-  1.12 (still evaluating)
# log(Z_2)   =          -27.50 +/-  1.27 (still evaluating)
# log(Z_3)   =          -27.93 +/-  1.16
# log(Z_4)   =          -38.48 +/-  1.09
# log(Z_5)   =          -46.42 +/-  0.95
# log(Z_6)   =         -155.23 +/-  1.21
#
#
#
# _____________________
# lives      |  6 | 26 |
# phantoms   | 26 |110 |
# posteriors |672 |782 |
# equals     | 15 | 94 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       6
# ndead      =                1072
# nposterior =                1072
# nequals    =                  34
# nlike      =               21275
# <nlike>    =          31.00   (           6.20 per slice )
# log(Z)     =          -25.61 +/-  1.10
# log(Z_1)   =          -26.02 +/-  1.13 (still evaluating)
# log(Z_2)   =          -27.34 +/-  1.27 (still evaluating)
# log(Z_3)   =          -27.93 +/-  1.16
# log(Z_4)   =          -38.48 +/-  1.09
# log(Z_5)   =          -46.42 +/-  0.95
# log(Z_6)   =         -155.23 +/-  1.21
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         1113                              |
# | log(Z) =          -25.39701 +/-            1.10720 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'polychord_output_directory/run1_model_3_w0_wa_-0.9_-0.2_wide_polychord_raw', with prefix 'run1_model_3_w0_wa_-0.9_-0.2_wide'
# [polychord] log(Z) = -25.5176 +/- 1.1072 ; Z in [2.7353479e-12, 2.5044428e-11] (68% C.L. log-gaussian)
# It took 6.58 hours to run
# [output] Output to be read-from/written-into folder 'polychord_output_directory', with prefix 'run1_model_3_w0_wa_-0.9_-0.2_narrow'
# [parameterization] *WARNING* There are repeated parameter labels: {'a_{s}': ['lnas', 'w0', 'wa']}
# [prior] *WARNING* External prior 'function' loaded. Mind that it might not be normalized!
# [likelihood_camb] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /Users/seanyi/Documents/polychord/PolyChordLite/build/lib.macosx-11.0-arm64-cpython-311/pypolychord
# [polychord] Storing raw PolyChord output in 'polychord_output_directory/run1_model_3_w0_wa_-0.9_-0.2_narrow_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {likelihood_CAMB: 0.942}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['omega_c', 'n_s', 'lnas', 'w0', 'wa']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      32
# nDims    :       5
# nDerived :       3
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to polychord_output_directory/run1_model_3_w0_wa_-0.9_-0.2_narrow_polychord_raw/run1_model_3_w0_wa_-0.9_-0.2_narrow.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            5
# started sampling
#
# ________________
# lives      | 32 |
# phantoms   |  4 |
# posteriors |289 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 289
# nposterior =                 289
# nequals    =                   1
# nlike      =                 337
# <nlike>    =           0.53   (           0.11 per slice )
# log(Z)     =       -46204.98 +/-  0.83
# log(Z_1)   =       -46204.98 +/-  0.83 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   | 89 |
# posteriors |322 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 322
# nposterior =                 322
# nequals    =                   1
# nlike      =                 876
# <nlike>    =          16.84   (           3.37 per slice )
# log(Z)     =       -23610.62 +/-  0.85
# log(Z_1)   =       -23610.62 +/-  0.85 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |116 |
# posteriors |355 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 355
# nposterior =                 355
# nequals    =                   1
# nlike      =                1442
# <nlike>    =          17.69   (           3.54 per slice )
# log(Z)     =        -9341.74 +/-  0.87
# log(Z_1)   =        -9341.74 +/-  0.87 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |153 |
# posteriors |388 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 388
# nposterior =                 388
# nequals    =                   1
# nlike      =                2170
# <nlike>    =          22.75   (           4.55 per slice )
# log(Z)     =        -5231.18 +/-  0.88
# log(Z_1)   =        -5231.18 +/-  0.88 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |110 |
# posteriors |421 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 421
# nposterior =                 421
# nequals    =                   1
# nlike      =                3098
# <nlike>    =          29.00   (           5.80 per slice )
# log(Z)     =        -2637.19 +/-  0.90
# log(Z_1)   =        -2637.19 +/-  0.90 (still evaluating)
#
#
#
# __________________________
# lives      |  5 | 16 | 11 |
# phantoms   | 18 | 58 | 51 |
# posteriors |436 |437 |426 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 457
# nposterior =                 457
# nequals    =                   1
# nlike      =                4127
# <nlike>    =          32.16   (           6.43 per slice )
# log(Z)     =        -1937.80 +/-  0.91
# log(Z_1)   =        -1937.80 +/-  0.91 (still evaluating)
# log(Z_2)   =        -2032.40 +/-  0.93 (still evaluating)
# log(Z_3)   =        -2106.56 +/-  0.91 (still evaluating)
#
#
#
# __________________________
# lives      |  8 | 12 | 12 |
# phantoms   | 32 | 53 | 46 |
# posteriors |442 |453 |439 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 492
# nposterior =                 492
# nequals    =                   1
# nlike      =                5020
# <nlike>    =          27.91   (           5.58 per slice )
# log(Z)     =         -773.64 +/-  0.93
# log(Z_1)   =         -773.71 +/-  0.96 (still evaluating)
# log(Z_2)   =         -776.84 +/-  0.96 (still evaluating)
# log(Z_3)   =        -1002.28 +/-  0.98 (still evaluating)
#
#
#
# __________________________
# lives      |  9 | 19 |  4 |
# phantoms   | 47 | 86 | 30 |
# posteriors |449 |463 |455 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 525
# nposterior =                 525
# nequals    =                   1
# nlike      =                5850
# <nlike>    =          25.94   (           5.19 per slice )
# log(Z)     =         -405.87 +/-  0.99
# log(Z_1)   =         -405.87 +/-  0.99 (still evaluating)
# log(Z_2)   =         -431.82 +/-  0.99 (still evaluating)
# log(Z_3)   =         -469.07 +/-  1.06 (still evaluating)
#
#
#
# __________________________
# lives      | 11 | 15 |  6 |
# phantoms   | 51 | 68 | 31 |
# posteriors |455 |485 |462 |
# equals     |  1 |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 560
# nposterior =                 560
# nequals    =                   1
# nlike      =                6772
# <nlike>    =          28.81   (           5.76 per slice )
# log(Z)     =         -230.68 +/-  1.01
# log(Z_1)   =         -230.68 +/-  1.01 (still evaluating)
# log(Z_2)   =         -244.02 +/-  1.10 (still evaluating)
# log(Z_3)   =         -249.05 +/-  1.09 (still evaluating)
#
#
#
# _____________________
# lives      | 13 | 19 |
# phantoms   | 68 | 80 |
# posteriors |467 |498 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 596
# nposterior =                 596
# nequals    =                   1
# nlike      =                7718
# <nlike>    =          29.56   (           5.91 per slice )
# log(Z)     =         -124.46 +/-  1.00
# log(Z_1)   =         -124.58 +/-  1.05 (still evaluating)
# log(Z_2)   =         -127.09 +/-  0.91 (still evaluating)
# log(Z_3)   =         -129.22 +/-  1.15
#
#
#
# _______________________________
# lives      | 13 | 11 |  5 |  3 |
# phantoms   | 53 | 41 | 25 |  9 |
# posteriors |479 |512 |503 |502 |
# equals     |  1 |  1 |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       5
# ndead      =                 631
# nposterior =                 631
# nequals    =                   1
# nlike      =                8765
# <nlike>    =          32.72   (           6.54 per slice )
# log(Z)     =          -74.82 +/-  0.89
# log(Z_1)   =          -75.64 +/-  1.16 (still evaluating)
# log(Z_2)   =          -75.92 +/-  0.91 (still evaluating)
# log(Z_3)   =          -77.59 +/-  1.08 (still evaluating)
# log(Z_4)   =          -79.53 +/-  1.06 (still evaluating)
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      | 16 | 16 |
# phantoms   | 72 | 79 |
# posteriors |492 |524 |
# equals     |  1 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 669
# nposterior =                 669
# nequals    =                   1
# nlike      =                9795
# <nlike>    =          32.19   (           6.44 per slice )
# log(Z)     =          -56.57 +/-  0.84
# log(Z_1)   =          -57.51 +/-  1.13 (still evaluating)
# log(Z_2)   =          -57.89 +/-  0.89 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  9 | 23 |
# phantoms   | 57 |114 |
# posteriors |511 |538 |
# equals     |  1 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 702
# nposterior =                 702
# nequals    =                   3
# nlike      =               10774
# <nlike>    =          30.59   (           6.12 per slice )
# log(Z)     =          -41.99 +/-  0.82
# log(Z_1)   =          -42.65 +/-  1.02 (still evaluating)
# log(Z_2)   =          -43.05 +/-  0.94 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  5 | 27 |
# phantoms   | 39 |147 |
# posteriors |519 |565 |
# equals     |  2 |  7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 737
# nposterior =                 737
# nequals    =                   6
# nlike      =               11748
# <nlike>    =          30.44   (           6.09 per slice )
# log(Z)     =          -35.50 +/-  0.76
# log(Z_1)   =          -36.09 +/-  0.82 (still evaluating)
# log(Z_2)   =          -36.67 +/-  1.07 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  4 | 28 |
# phantoms   | 33 |121 |
# posteriors |526 |590 |
# equals     |  2 |  7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 769
# nposterior =                 769
# nequals    =                   7
# nlike      =               12580
# <nlike>    =          26.00   (           5.20 per slice )
# log(Z)     =          -30.53 +/-  0.79
# log(Z_1)   =          -30.78 +/-  0.84 (still evaluating)
# log(Z_2)   =          -32.66 +/-  1.23 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  4 | 28 |
# phantoms   | 24 |108 |
# posteriors |531 |619 |
# equals     |  3 | 11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 803
# nposterior =                 803
# nequals    =                  10
# nlike      =               13502
# <nlike>    =          28.81   (           5.76 per slice )
# log(Z)     =          -26.47 +/-  0.78
# log(Z_1)   =          -26.83 +/-  0.84 (still evaluating)
# log(Z_2)   =          -28.19 +/-  1.19 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  8 | 24 |
# phantoms   | 40 | 87 |
# posteriors |536 |648 |
# equals     |  6 | 17 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 837
# nposterior =                 837
# nequals    =                  26
# nlike      =               14570
# <nlike>    =          33.38   (           6.67 per slice )
# log(Z)     =          -24.45 +/-  0.79
# log(Z_1)   =          -24.67 +/-  0.85 (still evaluating)
# log(Z_2)   =          -26.71 +/-  1.21 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  4 | 28 |
# phantoms   | 31 |143 |
# posteriors |542 |677 |
# equals     |  4 | 42 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 872
# nposterior =                 872
# nequals    =                  35
# nlike      =               15539
# <nlike>    =          30.28   (           6.06 per slice )
# log(Z)     =          -23.51 +/-  0.79
# log(Z_1)   =          -23.74 +/-  0.85 (still evaluating)
# log(Z_2)   =          -25.69 +/-  1.23 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  6 | 26 |
# phantoms   | 29 |117 |
# posteriors |549 |704 |
# equals     |  9 | 64 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 906
# nposterior =                 906
# nequals    =                  53
# nlike      =               16610
# <nlike>    =          33.47   (           6.69 per slice )
# log(Z)     =          -22.94 +/-  0.80
# log(Z_1)   =          -23.24 +/-  0.86 (still evaluating)
# log(Z_2)   =          -24.90 +/-  1.25 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  3 | 29 |
# phantoms   | 21 | 96 |
# posteriors |559 |727 |
# equals     | 18 | 79 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 939
# nposterior =                 939
# nequals    =                  77
# nlike      =               17486
# <nlike>    =          27.38   (           5.47 per slice )
# log(Z)     =          -22.56 +/-  0.81
# log(Z_1)   =          -22.90 +/-  0.86 (still evaluating)
# log(Z_2)   =          -24.39 +/-  1.27 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
# _____________________
# lives      |  2 | 30 |
# phantoms   | 20 |137 |
# posteriors |564 |755 |
# equals     | 22 | 97 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                 972
# nposterior =                 972
# nequals    =                  95
# nlike      =               18407
# <nlike>    =          28.78   (           5.76 per slice )
# log(Z)     =          -22.33 +/-  0.82
# log(Z_1)   =          -22.65 +/-  0.87 (still evaluating)
# log(Z_2)   =          -24.24 +/-  1.28 (still evaluating)
# log(Z_3)   =          -58.38 +/-  1.06
# log(Z_4)   =          -68.22 +/-  1.05
# log(Z_5)   =         -129.22 +/-  1.15
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         1008                              |
# | log(Z) =          -22.13927 +/-            0.82039 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'polychord_output_directory/run1_model_3_w0_wa_-0.9_-0.2_narrow_polychord_raw', with prefix 'run1_model_3_w0_wa_-0.9_-0.2_narrow'
# [polychord] log(Z) = -22.3674 +/- 0.820392 ; Z in [8.5049288e-11, 4.3878722e-10] (68% C.L. log-gaussian)
# It took 4.46 hours to run
# [output] Output to be read-from/written-into folder 'polychord_output_directory', with prefix 'run1_model_1_-0.9_-0.2'
# [likelihood_camb] Initialized external likelihood.
# [polychord] `pypolychord` module loaded successfully from /Users/seanyi/Documents/polychord/PolyChordLite/build/lib.macosx-11.0-arm64-cpython-311/pypolychord
# [polychord] Storing raw PolyChord output in 'polychord_output_directory/run1_model_1_-0.9_-0.2_polychord_raw'.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {likelihood_CAMB: 1.54}
# [polychord] Parameter blocks and their oversampling factors:
# [polychord] * 1 : ['omega_c', 'n_s', 'lnas']
# [polychord] Calling PolyChord...
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      32
# nDims    :       3
# nDerived :       2
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to polychord_output_directory/run1_model_1_-0.9_-0.2_polychord_raw/run1_model_1_-0.9_-0.2.resume
#
# generating live points
#
#
# all live points generated
#
# number of repeats:            5
# started sampling
#
# ________________
# lives      | 32 |
# phantoms   |  4 |
# posteriors |289 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 289
# nposterior =                 289
# nequals    =                   1
# nlike      =                 332
# <nlike>    =           0.38   (           0.07 per slice )
# log(Z)     =       -42629.05 +/-  0.83
# log(Z_1)   =       -42629.05 +/-  0.83 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   | 83 |
# posteriors |322 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 322
# nposterior =                 322
# nequals    =                   1
# nlike      =                 939
# <nlike>    =          18.97   (           3.79 per slice )
# log(Z)     =       -14233.43 +/-  0.85
# log(Z_1)   =       -14233.43 +/-  0.85 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |125 |
# posteriors |355 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 355
# nposterior =                 355
# nequals    =                   1
# nlike      =                1577
# <nlike>    =          19.94   (           3.99 per slice )
# log(Z)     =        -6356.33 +/-  0.87
# log(Z_1)   =        -6356.33 +/-  0.87 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |123 |
# posteriors |388 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 388
# nposterior =                 388
# nequals    =                   1
# nlike      =                2262
# <nlike>    =          21.41   (           4.28 per slice )
# log(Z)     =        -3018.63 +/-  0.88
# log(Z_1)   =        -3018.63 +/-  0.88 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |140 |
# posteriors |421 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 421
# nposterior =                 421
# nequals    =                   1
# nlike      =                2961
# <nlike>    =          21.84   (           4.37 per slice )
# log(Z)     =        -1497.30 +/-  0.90
# log(Z_1)   =        -1497.30 +/-  0.90 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |139 |
# posteriors |454 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 454
# nposterior =                 454
# nequals    =                   1
# nlike      =                3741
# <nlike>    =          24.38   (           4.88 per slice )
# log(Z)     =         -776.39 +/-  0.92
# log(Z_1)   =         -776.39 +/-  0.92 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |147 |
# posteriors |487 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 487
# nposterior =                 487
# nequals    =                   1
# nlike      =                4558
# <nlike>    =          25.53   (           5.11 per slice )
# log(Z)     =         -454.88 +/-  0.93
# log(Z_1)   =         -454.88 +/-  0.93 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |157 |
# posteriors |520 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 520
# nposterior =                 520
# nequals    =                   1
# nlike      =                5339
# <nlike>    =          24.41   (           4.88 per slice )
# log(Z)     =         -254.69 +/-  0.95
# log(Z_1)   =         -254.69 +/-  0.95 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |138 |
# posteriors |553 |
# equals     |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 553
# nposterior =                 553
# nequals    =                   2
# nlike      =                6144
# <nlike>    =          25.16   (           5.03 per slice )
# log(Z)     =         -123.93 +/-  0.80
# log(Z_1)   =         -123.93 +/-  0.80 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |124 |
# posteriors |586 |
# equals     |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 586
# nposterior =                 586
# nequals    =                   2
# nlike      =                6915
# <nlike>    =          24.09   (           4.82 per slice )
# log(Z)     =          -68.13 +/-  0.75
# log(Z_1)   =          -68.13 +/-  0.75 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |139 |
# posteriors |619 |
# equals     |  3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 619
# nposterior =                 619
# nequals    =                   6
# nlike      =                7726
# <nlike>    =          25.34   (           5.07 per slice )
# log(Z)     =          -43.52 +/-  0.64
# log(Z_1)   =          -43.52 +/-  0.64 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |140 |
# posteriors |652 |
# equals     |  5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 652
# nposterior =                 652
# nequals    =                   6
# nlike      =                8493
# <nlike>    =          23.97   (           4.79 per slice )
# log(Z)     =          -30.30 +/-  0.65
# log(Z_1)   =          -30.30 +/-  0.65 (still evaluating)
#
#
#
# ________________
# lives      | 32 |
# phantoms   |152 |
# posteriors |681 |
# equals     |  9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                 685
# nposterior =                 685
# nequals    =                  10
# nlike      =                9385
# <nlike>    =          27.88   (           5.58 per slice )
# log(Z)     =          -25.15 +/-  0.64
# log(Z_1)   =          -25.19 +/-  0.65 (still evaluating)
# log(Z_2)   =          -28.58 +/-  0.73
#
#
#
# ________________
# lives      | 32 |
# phantoms   |143 |
# posteriors |714 |
# equals     | 14 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                 718
# nposterior =                 718
# nequals    =                  16
# nlike      =               10190
# <nlike>    =          25.16   (           5.03 per slice )
# log(Z)     =          -21.62 +/-  0.65
# log(Z_1)   =          -21.62 +/-  0.65 (still evaluating)
# log(Z_2)   =          -28.58 +/-  0.73
#
#
#
# ________________
# lives      | 32 |
# phantoms   |133 |
# posteriors |747 |
# equals     | 36 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                 751
# nposterior =                 751
# nequals    =                  37
# nlike      =               10974
# <nlike>    =          24.50   (           4.90 per slice )
# log(Z)     =          -20.19 +/-  0.64
# log(Z_1)   =          -20.19 +/-  0.64 (still evaluating)
# log(Z_2)   =          -28.58 +/-  0.73
#
#
#
# ________________
# lives      | 32 |
# phantoms   |136 |
# posteriors |780 |
# equals     | 62 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                 784
# nposterior =                 784
# nequals    =                  65
# nlike      =               11759
# <nlike>    =          24.53   (           4.91 per slice )
# log(Z)     =          -19.66 +/-  0.64
# log(Z_1)   =          -19.66 +/-  0.64 (still evaluating)
# log(Z_2)   =          -28.58 +/-  0.73
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =          843                              |
# | log(Z) =          -19.28877 +/-            0.64996 |
# |____________________________________________________|
# [polychord] Loading PolyChord's results: samples and evidences.
# [polychord] Finished! Raw PolyChord output stored in 'polychord_output_directory/run1_model_1_-0.9_-0.2_polychord_raw', with prefix 'run1_model_1_-0.9_-0.2'
# [polychord] log(Z) = -19.2888 +/- 0.649961 ; Z in [2.191396e-09, 8.0402572e-09] (68% C.L. log-gaussian)
# It took 1.72 hours to run
